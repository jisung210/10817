# %% [markdown]
# <a href="https://colab.research.google.com/github/jisung210/10817/blob/main/20260923.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = set()
s1 = {3,2,2}
s2 = {9,1,3}
print(s1)
print(s2)
# Out:
# {2, 3}
# {9, 3, 1}

# %%
s1.add(10)
print(s1)
s1.update([2,1])
print(s1)
s1.discard(10)
print(s1)
s1.remove(3)
print(s1)
print(s1&s2)
print(s1|s2)
print(s1-s2)
s1.clear()
print(s1)
# Out:
# {10, 2, 3}
# {10, 1, 2, 3}
# {1, 2, 3}
# {1, 2}
# {1}
# {1, 2, 3, 9}
# {2}
# set()

# %%
a = set(['우유','빵','버터','빵','치즈','과자','우유'])
b = set(['빵','과일','야채','버터','우유','커피'])
print(a)
print(a&b)
# Out:
# {'과자', '버터', '치즈', '우유', '빵'}
# {'우유', '빵', '버터'}
