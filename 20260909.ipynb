# %% [markdown]
# <a href="https://colab.research.google.com/github/jisung210/10817/blob/main/20260909.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 6
b =1.5
c = 1+2j
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(a + 1, type(a + 1))
print(a + b, type(a / b))
print(a / 2, type(a / 2))
print(a // 2, type(a // 2))
# Out:
# 6 <class 'int'>
# 1.5 <class 'float'>
# (1+2j) <class 'complex'>
# 7 <class 'int'>
# 7.5 <class 'float'>
# 3.0 <class 'float'>
# 3 <class 'int'>

# %%
a = True
b = False
print(a, type(a))
print(b, type(b))
print(10 < 20, type(10 < 20))
print(20 < 10, type(20 < 10))
# Out:
# True <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>
# False <class 'bool'>

# %%
a = 'Hello'
b = ''
c = 10
d = 0
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
# True
# False
# True
# False

# %%
a = '100'
b = 'Python'
c = 'name is "짱구"' # c = 'name is '짱구''(오류 발생)
d = '''name is "코난"'''
print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 100 <class 'str'>
# Python <class 'str'>
# name is "짱구" <class 'str'>
# name is "코난" <class 'str'>

# %%
a = 'hello'
b = 'world'
print(a + b)
print(a * 3)
print(a < b)   # 두 문자열을 사전순(알파벳순 / 아스킷코드값)으로 비교
print('h' in a)
print('wor' not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
# 한 문자만 인덱싱 : 변수명[인덱스번호]
a = 'Hello Python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# P
# n

# %%
# 연속된 부분의 문자열을 슬라이싱 : 변수명[시작인덱스:종료인덱스]
a = 'Hello Python'
print(a[0:5])          # 0 ~ 4
print(a[6:])           # 6 ~ 끝
print(a[:5])           # 0 ~ 4
print(a[6:-4])         # 6 ~ 끝에서 5번째
print(a[0:9:2])        # 0 ~ 8(2간격)
# Out:
# Hello
# Python
# Hello
# Py
# HloPt

# %%
str = 'Python'
str.lower()
# Out:
# 'python'

# %%
a = input('주민등록번호 입력:')

print('연:20' + a[0:2]+'년')
print('월:' + a[2:4]+'월')
print('일:' + a[4:6]+'일')
# Out:
# 주민등록번호 입력:100111
# 연:2010년
# 월:01월
# 일:11일

# %%
a = input('문자를 입력하세요')
b = a[::-1]
c = b.replace('e','3').replace('o','0').replace('l','1')
print('암호문: ' + c)
# Out:
# 문자를 입력하세요weiokl
# 암호문: 1k0i3w
