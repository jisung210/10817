# %% [markdown]
# <a href="https://colab.research.google.com/github/jisung210/10817/blob/main/20260921.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = {}                        #공백 딕셔너리
b = {88:'seoul',24:'paris','num':[10,20]}
c = {'name':'kim','name':'lee'}
print(a,type(a))
print(len(b))               #키와 값 쌍의 개수
print(b[88])
print(c['name'])
# Out:
# {} <class 'dict'>
# 3
# seoul
# lee

# %%
a = {88:'london',20:'tokyo'}
a[88] = 'seoul'
a[24] = 'paris'
del a[20]
a.update({24:'busan'})
a.update({30:'suwon'})
print(a)
# Out:
# {88: 'seoul', 24: 'busan', 30: 'suwon'}

# %%
dic = {'grape':'포도','apple':'사과'}
print(dic)
print(sorted(dic))
print(sorted(dic,reverse=True))
print(sorted(dic.items()))
print('apple'in dic)
print(dic.items())
print(dic.get('apple','gg'))
# Out:
# {'grape': '포도', 'apple': '사과'}
# ['apple', 'grape']
# ['grape', 'apple']
# [('apple', '사과'), ('grape', '포도')]
# True
# dict_items([('grape', '포도'), ('apple', '사과')])
# 사과

# %%
dic = {'grape':'포도','apple':'사과'}
print(dic.keys())
print(dic.values())
print(sorted(dic.values()))
print(dic.items())
p = dic.pop('apple')
print(p)
print(dic)
print(dic.get('grape'))
print(dic.get('apple'))
print(dic.get('apple','없음'))
dic.clear()
print(dic)
# Out:
# dict_keys(['grape', 'apple'])
# dict_values(['포도', '사과'])
# ['사과', '포도']
# dict_items([('grape', '포도'), ('apple', '사과')])
# 사과
# {'grape': '포도'}
# 포도
# None
# 없음
# {}

# %%
a = {'burger':5000,'pizza':8000,'pasta':7000}
a.update({'pizza':10000})
a.update({'coke':2000})
del a['burger']
print(sorted(a.values(),reverse=True))
# Out:
# [10000, 7000, 2000]
