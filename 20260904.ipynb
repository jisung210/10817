# %% [markdown]
# <a href="https://colab.research.google.com/github/jisung210/10817/blob/main/20260904.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input('이름')
b = input('나이')
print(a,'님 안녕하세요')
print(20-int(b),'년 후면 20살이시네요!')
# Out:
# 이름이지성
# 나이17
# 이지성 님 안녕하세요
# 3 년 후면 20살이시네요!

# %%
a = int(input('가결(원):'))
b = int(input('할인율(%):'))
print(f'출력 : {a+b}')
# Out:
# 가결(원):1010
# 할인율(%):1010
# 출력 : 2020

# %%
sec = int(input('시간을 초 단위로 입력하세요:'))
minutes = sec // 60
seconds = sec % 60
print(f'{minutes}분 {seconds}초')
# Out:
# 시간을 초 단위로 입력하세요:3790
# 63분 10초

# %%
print(7/3)
print(7//3)
print(7%2)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
print('###########################')
print('[한양과학기술고등학교 학생증]')
a = input('*학번:')
b = input('*성명:')
c = input('*소속:')
print('위 사람은 본 학교의 학생임을 증명함')
print('############################')
# Out:
# ###########################
# [한양과학기술고등학교 학생증]
# *학번:10817
# *성명:이지성
# *소속:스마트전자과
# 위 사람은 본 학교의 학생임을 증명함
# ############################

# %%
a = input('이름:')
b = input('학번:')
c = input('소속:')
print('###########################')
print('[한양과학기술고등학교 학생증]')
print(f'  *학번: {a}')
print(f'  *성명: {b}')
print(f'  *소속: {c}')
print('위 사람은 본 학교의 학생임을 증명함')
print('############################')
# Out:
# 이름:이지성
# 학번:10817
# 소속:스마트전자과
# ###########################
# [한양과학기술고등학교 학생증]
#   *학번: 이지성
#   *성명: 10817
#   *소속: 스마트전자과
# 위 사람은 본 학교의 학생임을 증명함
# ############################
