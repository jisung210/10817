# %% [markdown]
# <a href="https://colab.research.google.com/github/jisung210/10817/blob/main/20260902ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보','프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 3+7
# 10 20 30 정보 프로그래밍

# %%
print('한양과학기술고등학교','1학년','이지성')
print('체질량 지수(BMI):',60/(170+170*60))
# Out:
# 한양과학기술고등학교 1학년 이지성
# 체질량 지수(BMI): 0.0057859209257473485

# %%
print('현재 온도는 %d도 입니다.'%20)
print('현재 온도는 {}도 입니다.'.format(20))
print(f'현재 온도는 {20}도 입니다.')
# Out:
# 현재 온도는 20도 입니다.
# 현재 온도는 20도 입니다.
# 현재 온도는 20도 입니다.

# %%
a = 20
b = 50
print('현재 온도는 %d도, 습도는 %d%% 입니다.'%(a,b))
print('현재 온도는 {}도, 습도는 {}% 입니다.'.format(a,b))
print(f'현재 온도는 {a}도, 습도는 {b}% 입니다.')
# Out:
# 현재 온도는 20도, 습도는 50% 입니다.
# 현재 온도는 20도, 습도는 50% 입니다.
# 현재 온도는 20도, 습도는 50% 입니다.

# %%
c = 90
d = 3.141592
print(f'직각은 {c}도, 원주율은 {d:0.2f}입니다.')
# Out:
# 직각은 90도, 원주율은 3.14입니다.

# %%
print('동해 물과 \'백두산\'이')
print('마르고 닳도록')
print('하느님이 보우하사 \n우리나라 만세')
print('무궁화 삼천리', end = ' ')
print('화려 강산')
print('대한 사람,"대한"으로 길이 보전하세.')
print('2026','05','20',sep='-')
# Out:
# 동해 물과 '백두산'이
# 마르고 닳도록
# 하느님이 보우하사
# 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람,"대한"으로 길이 보전하세.
# 2026-05-20

# %%
print('############################')
print('  [한양과학기술고등학교 학생증]')
print('     • 학번:10817')
print('     • 성명:이지성')
print('     • 소속:스마트전자과')
print('위 사람은 본 학교의 학생임을 증명함')
print('############################')
# Out:
# ############################
#   [한양과학기술고등학교 학생증]
#      • 학번:10817
#      • 성명:이지성
#      • 소속:스마트전자과
# 위 사람은 본 학교의 학생임을 증명함
# ############################
